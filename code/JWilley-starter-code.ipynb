# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# I’ll be taking the perspective of a state board of education, we are considering partnering with the SAT or ACT to increase participation in college entrance exams.  The purpose of this presentation is to determine whether to make one of these exams mandatory for high school graduation, and, if so, should it be the SAT or ACT.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*
#
# There are multiple reasons to agree to a contract to mandate either the ACT or SAT.  These tests are sometimes used as statewide assessments rather than states creating their own tests  This reduces the burden on the state for devising and administering another statewide benchmark test. Also, teachers are already teaching toward the test and students can be more familiar with it. Students/teachers will have one less test to worry about.  Finally, states with 100% participation rate show lower overall scores. This highlights disparities in educational achievement, and provides a metric to aim for.  (https://www.washingtonpost.com/local/education/growing-number-of-states-fund-act-college-admission-testing-for-11th-grade-students/2014/08/19/eb0edcba-27a7-11e4-86ca-6f03cbd15c1a_story.html)
#
# By partnering with these test boards, states are able to negotiate reduced prices for the test and administer them for free to students.  This has multiple benefits.
# Students who may not have had resources to pay for the test now don’t have to worry about cost. Also, students who may not have otherwise  considered going to college may now have more incentive to apply. At the same time, colleges may be looking at students they otherwise wouldn’t have. The ACT currently has a contract with 20 states, which results in high school students having access to free testing and study materials (https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice)
#
# Several states have recently transitioned from the ACT to the SAT.  There are several reasons for this:
# -The SAT was redesigned in 2016 to more closely align with Common Core standards, which these and many other staes uses as part of their state-wide standards. In the past it had been considered more a test for aptitude than a benchmark for knowledge
# -In 2014, The Khan Academy partnered with Collegeboard to provide free online resources and tutoring for students to prep for the SATs
# -The College Board offered a better contract to the state than ACT, Inc.
# (https://www.coloradokids.org/wp-content/uploads/2016/01/ACTvsSAT_FINAL.pdf)

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
# ###
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`bach_degree_25-34_2018`](./data/act_2017.xlsx): Population(Age 25-34) with Bachelor's or higher by state
# * [`college_bound_rates_2018`](./data/act_2017.xlsx): % of HS Grads going directly to college by state

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# These tests are sometimes used as statewide assessments rather than states creating their own tests
# -This reduces the burden on the state for devising and administering another statewide benchmark test.
# -Because of this, teachers are already teaching toward the test and students can be more familiar with it. Students/teachers will have one less test to worry about
# -Added benefit – as we saw before, States with 100% participation rate show lower overall scores. -- This highlights disparities in educational achievement, and provides a metric to aim for.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
test_list = [1, 2, 3, 4, 5]

def list_mean(my_list):
    return sum(my_list) / len(my_list)
    
list_mean(test_list)
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(my_list):
    n = len(my_list)
    mean = list_mean(my_list)
    sum_n = 0
    
    for i in my_list:
        sum_n += (i - mean)**2 
    return (sum_n / n)**(1/2)

std_dev(test_list)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
test_pct = '30.45%'
def create_float(pct_string):
    try:
        return float(pct_string.strip('%')) /100
    except(ValueError, NameError, AttributeError):
        return None

print(create_float(test_pct))
type(create_float(test_pct))
# Out:
# 0.3045
# float

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2019 = pd.read_csv('../data/sat_2019.csv')
college_rates = pd.read_excel('../data/college_bound_rates_2018.xlsx')
bach_deg = pd.read_excel('../data/bach_degree_25-34_2018.xlsx')

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
college_rates.head()
# Out:
#         State  Percent of High School Graduates Going Directly to College (%)  \
# 0     Alabama                                              65.95
# 1      Alaska                                              41.14
# 2     Arizona                                              50.09
# 3    Arkansas                                              63.13
# 4  California                                              66.01
#
#    Projected High School Graduates - 2018  \
# 0                                   48690
# 1                                    7758
# 2                                   68985
# 3                                   31315
# 4                                  431009
#
#    First-Time Freshmen Directly from High School Enrolled Anywhere in the US - Fall 2018
# 0                                              32111
# 1                                               3192
# 2                                              34558
# 3                                              19770
# ...

# %%
bach_deg.head()
# Out:
#       State  % Estimate, Population Age 25-34, Bachelor's Degree and Higher  \
# 0   Alabama                                              27.15
# 1    Alaska                                              26.96
# 2   Arizona                                              29.12
# 3  Arkansas                                              25.96
# 4   Average                                                NaN
#
#    Estimate, Population Age 25-34, Bachelor's Degree and Higher
# 0                                           172677.0
# 1                                            31724.0
# 2                                           285226.0
# 3                                           102024.0
# 4                                                NaN

# %% [markdown]
# #### Check for missing values

# %%
print(sat_2017.isna().sum().sum())
print(sat_2018.isna().sum().sum())
print(sat_2019.isna().sum().sum())
# Out:
# 0
# 0
# 0

# %%
print(act_2017.isna().sum().sum())
print(act_2018.isna().sum().sum())
print(act_2018.isna().sum().sum())
# Out:
# 0
# 0
# 0

# %%
print(bach_deg.isna().sum().sum())
print(college_rates.isna().sum().sum())
# Out:
# 2
# 0

# %% [markdown]
# #### Check for any obvious issues with the observations

# %%
print(sat_2017.describe(), '2017')
print(sat_2018.describe(), '2018')
print(sat_2019.describe(), '2019')
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000 2017
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# ...

# %%
print(act_2017.describe(), '2017')
print(act_2018.describe(), '2018')
print(act_2019.describe(), '2019')
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000 2017
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000 2018
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000 2019

# %%
print(bach_deg.describe())
# Out:
#        % Estimate, Population Age 25-34, Bachelor's Degree and Higher  \
# count                                          50.000000
# mean                                           34.629400
# std                                             6.825142
# min                                            23.240000
# 25%                                            29.580000
# 50%                                            34.170000
# 75%                                            38.827500
# max                                            53.460000
#
#        Estimate, Population Age 25-34, Bachelor's Degree and Higher
# count                                       5.000000e+01
# mean                                        3.257742e+05
# std                                         4.015220e+05
# min                                         2.119400e+04
# 25%                                         6.492425e+04
# 50%                                         1.851935e+05
# ...

# %%
print(college_rates.describe())
# Out:
#        Percent of High School Graduates Going Directly to College (%)  \
# count                                          51.000000
# mean                                           62.349608
# std                                             7.816671
# min                                            41.140000
# 25%                                            58.070000
# 50%                                            62.580000
# 75%                                            66.865000
# max                                            80.470000
#
#        Projected High School Graduates - 2018  \
# count                            5.100000e+01
# mean                             1.354390e+05
# std                              4.810286e+05
# min                              5.864000e+03
# 25%                              2.079000e+04
# 50%                              4.638000e+04
# 75%                              8.261300e+04
# max                              3.456347e+06
#
# ...

# %% [markdown]
# #### Fix any errors identified

# %%
#find bad min value of 52 in sat_2017 math
sat_2017[sat_2017.eq(52).any(1)]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
#find bad min value of 2.3 in act_2017 science
act_2017[act_2017.eq(2.3).any(1)]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
#correcting bad values with actual values from database source
sat_2017.loc[sat_2017['State'] == 'Maryland', 'Math'] = 524
act_2017.loc[act_2017['State'] == 'Maryland', 'Science'] = 23.2

# %%
#locate rows with missing values in bach_deg
bach_deg[bach_deg.isnull().any(axis=1)]
# Out:
#      State  % Estimate, Population Age 25-34, Bachelor's Degree and Higher  \
# 4  Average                                                NaN
#
#    Estimate, Population Age 25-34, Bachelor's Degree and Higher
# 4                                                NaN

# %%
#Deleting unnecessary row 'Average'
bach_deg.drop(4, inplace=True)

# %%
bach_deg.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Display data types of each feature

# %%
print('2017', sat_2017.dtypes)
print('2018', sat_2018.dtypes)
print('2019', sat_2019.dtypes)
# Out:
# 2017 State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# 2018 State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# 2019 State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
print('2017', act_2017.dtypes)
print('2018', act_2018.dtypes)
print('2019', act_2019.dtypes)
# Out:
# 2017 State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
# 2018 State             object
# Participation     object
# Composite        float64
# dtype: object
# 2019 State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
print(bach_deg.dtypes)
print(college_rates.dtypes)
# Out:
# State                                                              object
# % Estimate, Population Age 25-34, Bachelor's Degree and Higher    float64
# Estimate, Population Age 25-34, Bachelor's Degree and Higher      float64
# dtype: object
# State                                                                                     object
# Percent of High School Graduates Going Directly to College (%)                           float64
# Projected High School Graduates - 2018                                                     int64
# First-Time Freshmen Directly from High School Enrolled Anywhere in the US - Fall 2018      int64
# dtype: object

# %% [markdown]
# #### Fix any incorrect data types found

# %%
#converting ints to floats
sat_2017[['Evidence-Based Reading and Writing', 'Math', 'Total']] = sat_2017[['Evidence-Based Reading and Writing', 'Math','Total']].astype(float)
sat_2018[['Evidence-Based Reading and Writing', 'Math', 'Total']] = sat_2018[['Evidence-Based Reading and Writing', 'Math','Total']].astype(float)
sat_2019[['EBRW', 'Math', 'Total']] = sat_2019[['EBRW', 'Math','Total']].astype(float)

# %%
#Converting % to floats
sat_2017['Participation'] = sat_2017['Participation'].map(create_float)
sat_2018['Participation'] = sat_2018['Participation'].map(create_float)
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(create_float)

# %%
print('2017', sat_2017.dtypes)
print('2018', sat_2018.dtypes)
print('2019', sat_2019.dtypes)
# Out:
# 2017 State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object
# 2018 State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object
# 2019 State                  object
# Participation Rate    float64
# EBRW                  float64
# Math                  float64
# Total                 float64
# dtype: object

# %%
#Converting % to floats
act_2017['Participation'] = act_2017['Participation'].map(create_float)
act_2018['Participation'] = act_2018['Participation'].map(create_float)
act_2019['Participation'] = act_2019['Participation'].map(create_float)

# %%
print('2017', act_2017.dtypes)
print('2018', act_2018.dtypes)
print('2019', act_2019.dtypes)
# Out:
# 2017 State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
# 2018 State             object
# Participation    float64
# Composite        float64
# dtype: object
# 2019 State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
#Moving decimal to change from %
bach_deg['% Estimate, Population Age 25-34, Bachelor\'s Degree and Higher'] = bach_deg['% Estimate, Population Age 25-34, Bachelor\'s Degree and Higher']/100
college_rates['Percent of High School Graduates Going Directly to College (%)'] = college_rates['Percent of High School Graduates Going Directly to College (%)']/100

# %%
#Fixing bad value type in wyoming composite
act_2017.loc[act_2017['State'] == 'Wyoming', 'Composite'] = 20.2
act_2017['Composite'] = act_2017['Composite'].astype(float)

# %% [markdown]
# #### Rename Columns

# %%
sat_2017.columns = ['state', 'sat_part_17', 'sat_ebrw_17', 'sat_math_17', 'sat_total_17']
sat_2018.columns = ['state', 'sat_part_18', 'sat_ebrw_18', 'sat_math_18', 'sat_total_18']
sat_2019.columns = ['state', 'sat_part_19', 'sat_ebrw_19', 'sat_math_19', 'sat_total_19']

# %%
act_2017.columns = ['state', 'act_part_17', 'act_engl_17', 'act_math_17', 'act_read_17', 'act_scie_17', 'act_comp_17']
act_2018.columns = ['state', 'act_part_18', 'act_comp_18']
act_2019.columns = ['state', 'act_part_19', 'act_comp_19']

# %%
bach_deg.columns = ['state', 'perc_bach', 'pop_bach']

# %%
college_rates.columns = ['state', 'perc_college_bound', 'tot_hs_grads', 'tot_college_bound']

# %% [markdown]
# #### Drop unnecessary rows

# %%
#act_2017 national(0)
act_2017.drop(0, inplace=True)
act_2017.reset_index(drop=True, inplace=True)

#act_2018 duplicate Maine(20)
act_2018.drop(20, inplace=True)
act_2018.reset_index(drop=True, inplace=True)

#act_2019 national(51)
act_2019.drop(51, inplace=True)
act_2019.reset_index(drop=True, inplace=True)

#college_rates nation(50)
college_rates.drop(50, inplace=True)
college_rates.reset_index(drop=True, inplace=True)

#sat_2019 virgin islands(47), puerto rico(39)
sat_2019.drop(47, inplace=True)
sat_2019.drop(39, inplace=True)
sat_2019.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Merge dataframes

# %%
#referenced link for merging more than 2 dataframes   https://stackoverflow.com/questions/23668427/pandas-three-way-joining-multiple-dataframes-on-columns
sat_dfs = pd.merge(pd.merge(sat_2017, sat_2018, on='state'), sat_2019, on='state')

# %%
act_dfs = pd.merge(pd.merge(act_2017, act_2018, on='state'), act_2019, on='state')

# %%
college_dfs = pd.merge(college_rates, bach_deg, on='state')

# %%
all_dfs = pd.merge(pd.merge(sat_dfs, act_dfs,on='state'), college_dfs, on='state')

# %% [markdown]
# #### Additional cleaning

# %%
#to reduce the amount of data, we will only look at composite ACT and total SAT scores
all_dfs = all_dfs.drop(columns = ['sat_ebrw_17','sat_math_17','sat_ebrw_18','sat_math_18','sat_ebrw_19','sat_math_19',
                      'act_engl_17','act_math_17','act_read_17','act_scie_17'])

# %%
all_dfs.shape
# Out:
# (50, 18)

# %%
sat_dfs.shape
# Out:
# (51, 13)

# %%
act_dfs.shape
# Out:
# (50, 11)

# %%
college_dfs.shape
# Out:
# (50, 6)

# %%
#creating new dataframe with only test participation rates, college attendance rates, and bachelor's attainment rates
testpart_college = all_dfs.drop(columns = [ 'sat_total_17', 'sat_total_18', 'sat_total_19', 'act_comp_17', 'act_comp_18', 'act_comp_19', 'tot_hs_grads', 'tot_college_bound', 'pop_bach'])

# %%
testpart_college.head()
# Out:
#         state  sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# 0     Alabama         0.05         0.06         0.07         1.00
# 1      Alaska         0.38         0.43         0.41         0.65
# 2     Arizona         0.30         0.29         0.31         0.62
# 3    Arkansas         0.03         0.05         0.06         1.00
# 4  California         0.53         0.60         0.63         0.31
#
#    act_part_18  act_part_19  perc_college_bound  perc_bach
# 0         1.00         1.00              0.6595     0.2715
# 1         0.33         0.38              0.4114     0.2696
# 2         0.66         0.73              0.5009     0.2912
# 3         1.00         1.00              0.6313     0.2596
# 4         0.27         0.23              0.6601     0.3663

# %% [markdown]
# #### Save cleaned dataframes as csv

# %%
all_dfs.to_csv('../new_dfs/all_dfs.csv')
sat_dfs.to_csv('../new_dfs/sat_dfs.csv')
act_dfs.to_csv('../new_dfs/act_dfs.csv')
college_dfs.to_csv('../new_dfs/college_dfs.csv')
testpart_college.to_csv('../new_dfs/testpart_college.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|all_dfs|State|
# |sat_part_17|float|all_dfs / testpart_college|2017 SAT participation rate|
# |sat_total_17|int|all_dfs|2017 average SAT total score|
# |sat_part_18|float|all_dfs / testpart_college|2018 SAT participation rate|
# |sat_total_18|int|all_dfs|2018 average SAT total score|
# |sat_part_19|float|all_dfs / testpart_college|2019 SAT participation rate|
# |sat_total_19|int|all_dfs|2019 average SAT total score|
# |act_part_17|float|all_dfs / testpart_college|2017 ACT participation rate|
# |act_comp_17|float|all_dfs|2017 average ACT composite score|
# |act_part_18|float|all_dfs / testpart_college|2018 ACT participation rate|
# |act_comp_18|float|all_dfs|2018 average ACT composite score|
# |act_part_19|float|all_dfs / testpart_college|2019 ACT participation rate|
# |act_comp_19|float|all_dfs|2019 average ACT composite score|
# |perc_college_bound|float|all_dfs|Estimated rate of high school graduates going directly to college in 2018|
# |total_hs_grads|int|all_dfs|2018 Projected number of students graduating high school in 2018|
# |tot_college_bound|int|all_dfs|Projected number of high school graduates going directly to college in 2018|
# |perc_bach|float|all_dfs|Estimated percentage of the population age 25-34 with Bachelor's degree or higher in 2018|
# |pop_bach|float|all_dfs|Estimated number of people age 25-34 with Bachelor's degree or higher in 2018|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# #### Summary statistics for each column

# %%
all_dfs.describe()
# Out:
#        sat_part_17  sat_total_17  sat_part_18  sat_total_18  sat_part_19  \
# count    50.000000     50.000000    50.000000     50.000000    50.000000
# mean      0.386000   1129.620000     0.448200   1122.880000     0.481600
# std       0.345602     89.913085     0.370976     92.845634     0.386002
# min       0.020000    996.000000     0.020000    998.000000     0.020000
# 25%       0.040000   1057.000000     0.042500   1062.250000     0.052500
# 50%       0.340000   1107.500000     0.500000   1098.500000     0.525000
# 75%       0.650000   1214.000000     0.745000   1207.000000     0.817500
# max       1.000000   1295.000000     1.000000   1298.000000     1.000000
#
#        sat_total_19  act_part_17  act_comp_17  act_part_18  act_comp_18  \
# count     50.000000    50.000000    50.000000    50.000000    50.000000
# mean    1115.840000     0.659200    21.466000     0.623200    21.454000
# std       96.142403     0.321107     2.004241     0.341141     2.111312
# ...

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# #### Applying std_dev function to each column

# %%
sd = {'sat_part_17': std_dev(all_dfs['sat_part_17']),
      'sat_total_17': std_dev(all_dfs['sat_total_17']),
     'sat_part_18': std_dev(all_dfs['sat_part_18']),
      'sat_total_18': std_dev(all_dfs['sat_total_18']),
     'sat_part_19': std_dev(all_dfs['sat_part_19']),
      'sat_total_19': std_dev(all_dfs['sat_total_19']),
     'act_part_17': std_dev(all_dfs['act_part_17']),
      'act_comp_17': std_dev(all_dfs['act_comp_17']),
     'act_part_18': std_dev(all_dfs['act_part_18']),
      'act_comp_18': std_dev(all_dfs['act_comp_18']),
     'act_part_19': std_dev(all_dfs['act_part_19']),
      'act_comp_18': std_dev(all_dfs['act_comp_18']),
      'perc_college_bound': std_dev(all_dfs['perc_college_bound']),
      'tot_hs_grads': std_dev(all_dfs['tot_hs_grads']),
      'tot_college_bound': std_dev(all_dfs['tot_college_bound']),
      'perc_bach': std_dev(all_dfs['perc_bach']),
      'pop_bach': std_dev(all_dfs['pop_bach'])}
sd
# Out:
# {'sat_part_17': 0.3421286307808805,
#  'sat_total_17': 89.00941298536914,
#  'sat_part_18': 0.36724754594142633,
#  'sat_total_18': 91.91248881408882,
#  'sat_part_19': 0.38212228409240934,
#  'sat_total_19': 95.17612305615312,
#  'act_part_17': 0.3178794740149165,
#  'act_comp_17': 1.9840977798485642,
#  'act_part_18': 0.33771254048376703,
#  'act_comp_18': 2.090091864009809,
#  'act_part_19': 0.3430510166141473,
#  'perc_college_bound': 0.07814463963702181,
#  'tot_hs_grads': 80053.62200925326,
#  'tot_college_bound': 51496.32201439244,
#  'perc_bach': 0.06756545392432438,
#  'pop_bach': 397486.53959414986}

# %%
#referenced link to slice columns     https://stackoverflow.com/questions/10665889/how-to-take-column-slices-of-dataframe-in-pandas
all_dfs.loc[:, 'sat_part_17': 'pop_bach'].std()
# Out:
# sat_part_17                0.345602
# sat_total_17              89.913085
# sat_part_18                0.370976
# sat_total_18              92.845634
# sat_part_19                0.386002
# sat_total_19              96.142403
# act_part_17                0.321107
# act_comp_17                2.004241
# act_part_18                0.341141
# act_comp_18                2.111312
# act_part_19                0.346534
# act_comp_19                2.197267
# perc_college_bound         0.078938
# tot_hs_grads           80866.369973
# tot_college_bound      52019.140718
# perc_bach                  0.068251
# pop_bach              401522.039396
# dtype: float64

# %% [markdown]
# ######

# %%
all_dfs.sort_values('sat_total_18', ascending=False).head(10)
# Out:
#            state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 22     Minnesota         0.03        1295.0         0.04        1298.0
# 48     Wisconsin         0.03        1291.0         0.03        1294.0
# 33  North Dakota         0.02        1256.0         0.02        1283.0
# 14          Iowa         0.02        1275.0         0.03        1265.0
# 15        Kansas         0.04        1260.0         0.04        1265.0
# 24      Missouri         0.03        1271.0         0.04        1262.0
# 49       Wyoming         0.03        1230.0         0.03        1257.0
# 26      Nebraska         0.03        1253.0         0.03        1252.0
# 16      Kentucky         0.04        1247.0         0.04        1248.0
# 40  South Dakota         0.03        1216.0         0.03        1240.0
#
#     sat_part_19  sat_total_19  act_part_17  act_comp_17  act_part_18  \
# 22         0.04        1284.0         1.00         21.5         0.99
# ...

# %%
all_dfs.sort_values('act_comp_18', ascending=False).head(10)
# Out:
#             state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 6     Connecticut         1.00        1041.0         1.00        1053.0
# 20  Massachusetts         0.76        1107.0         0.80        1125.0
# 28  New Hampshire         0.96        1052.0         0.96        1063.0
# 31       New York         0.67        1052.0         0.79        1068.0
# 21       Michigan         1.00        1005.0         1.00        1011.0
# 38   Rhode Island         0.71        1062.0         0.97        1018.0
# 44        Vermont         0.60        1114.0         0.64        1120.0
# 18          Maine         0.95        1012.0         0.99        1013.0
# 12       Illinois         0.09        1115.0         0.99        1019.0
# 5        Colorado         0.11        1201.0         1.00        1025.0
#
#     sat_part_19  sat_total_19  act_part_17  act_comp_17  act_part_18  \
# 6          1.00        1046.0         0.31         25.2         0.26
# ...

# %% [markdown]
# ##### Listing top 10 states for average scores in both tests in 2018. No states appear in top 10 for both tests. States with high average scores tend to have lower than average participation rates in the respective tests.

# %% [markdown]
# #####

# %%
all_dfs[['state', 'sat_total_18', 'sat_part_18', 'perc_college_bound', 'perc_bach']].sort_values('sat_part_18', ascending=False).head(10)
# Out:
#             state  sat_total_18  sat_part_18  perc_college_bound  perc_bach
# 5        Colorado        1025.0         1.00              0.5798     0.4277
# 6     Connecticut        1053.0         1.00              0.7805     0.4345
# 7        Delaware         998.0         1.00              0.7093     0.3273
# 21       Michigan        1011.0         1.00              0.6479     0.3366
# 11          Idaho        1001.0         1.00              0.4393     0.2781
# 18          Maine        1013.0         0.99              0.5880     0.3629
# 12       Illinois        1019.0         0.99              0.6172     0.4240
# 38   Rhode Island        1018.0         0.97              0.6981     0.3884
# 28  New Hampshire        1063.0         0.96              0.6120     0.3879
# 29     New Jersey        1094.0         0.82              0.7402     0.4722

# %%
all_dfs[['state', 'act_comp_18', 'act_part_18', 'perc_college_bound', 'perc_bach']].sort_values('act_part_18', ascending=False).head(13)
# Out:
#              state  act_comp_18  act_part_18  perc_college_bound  perc_bach
# 0          Alabama         19.1          1.0              0.6595     0.2715
# 16        Kentucky         20.2          1.0              0.6408     0.2859
# 48       Wisconsin         20.5          1.0              0.5828     0.3516
# 43            Utah         20.4          1.0              0.4696     0.3414
# 41       Tennessee         19.6          1.0              0.6865     0.3136
# 39  South Carolina         18.3          1.0              0.6889     0.3096
# 35        Oklahoma         19.3          1.0              0.5727     0.2614
# 34            Ohio         20.3          1.0              0.6324     0.3379
# 32  North Carolina         19.1          1.0              0.6329     0.3445
# 27          Nevada         17.7          1.0              0.5816     0.2348
# 26        Nebraska         20.1          1.0              0.6258     0.3866
# ...

# %% [markdown]
# ##### Listing top ten states for participation in each test in 2018. Scores tend to be lower than average when participation rates are high.

# %% [markdown]
# #####

# %%
all_dfs[all_dfs['sat_part_18'] >= 0.95]
# Out:
#             state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 5        Colorado         0.11        1201.0         1.00        1025.0
# 6     Connecticut         1.00        1041.0         1.00        1053.0
# 7        Delaware         1.00         996.0         1.00         998.0
# 11          Idaho         0.93        1005.0         1.00        1001.0
# 12       Illinois         0.09        1115.0         0.99        1019.0
# 18          Maine         0.95        1012.0         0.99        1013.0
# 21       Michigan         1.00        1005.0         1.00        1011.0
# 28  New Hampshire         0.96        1052.0         0.96        1063.0
# 38   Rhode Island         0.71        1062.0         0.97        1018.0
#
#     sat_part_19  sat_total_19  act_part_17  act_comp_17  act_part_18  \
# 5          1.00        1024.0         1.00         20.8         0.30
# 6          1.00        1046.0         0.31         25.2         0.26
# ...

# %%
all_dfs[all_dfs['act_part_18'] >= 0.95]
# Out:
#              state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 0          Alabama         0.05        1165.0         0.06        1166.0
# 3         Arkansas         0.03        1208.0         0.05        1169.0
# 16        Kentucky         0.04        1247.0         0.04        1248.0
# 17       Louisiana         0.04        1198.0         0.04        1210.0
# 22       Minnesota         0.03        1295.0         0.04        1298.0
# 23     Mississippi         0.02        1242.0         0.03        1236.0
# 24        Missouri         0.03        1271.0         0.04        1262.0
# 25         Montana         0.10        1196.0         0.10        1198.0
# 26        Nebraska         0.03        1253.0         0.03        1252.0
# 27          Nevada         0.26        1116.0         0.23        1140.0
# 32  North Carolina         0.49        1081.0         0.52        1098.0
# 33    North Dakota         0.02        1256.0         0.02        1283.0
# ...

# %%
all_dfs[ (all_dfs['act_part_18'] >= 0.5)  &  (all_dfs['sat_part_18'] >= 0.5)  ]
# Out:
#              state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 8          Florida         0.83        1017.0         0.56        1099.0
# 9          Georgia         0.61        1050.0         0.70        1064.0
# 10          Hawaii         0.55        1085.0         0.56        1010.0
# 32  North Carolina         0.49        1081.0         0.52        1098.0
# 39  South Carolina         0.50        1064.0         0.55        1070.0
#
#     sat_part_19  sat_total_19  act_part_17  act_comp_17  act_part_18  \
# 8          1.00         999.0         0.73         19.8         0.66
# 9          0.71        1058.0         0.55         21.4         0.53
# 10         0.54        1100.0         0.90         19.0         0.89
# 32         0.51        1100.0         1.00         19.1         1.00
# 39         0.68        1030.0         1.00         18.7         1.00
#
#     act_comp_18  act_part_19  act_comp_19  perc_college_bound  tot_hs_grads  \
# ...

# %% [markdown]
# ##### Comparing states where participation in the ACT and SAT are near 100%.  In 2018, there were no states that had higher than 95% participation in both tests, indicating that many states may require one test but not the other. 5 states had greater than 50% participation in both tests.

# %% [markdown]
# ######

# %%
#Narrowing data to compare participation with college rates
part_colg = all_dfs[['state', 'sat_part_17', 'sat_part_18', 'sat_part_19', 'act_part_17', 'act_part_18', 'act_part_19', 'perc_college_bound', 'perc_bach']]
part_colg.head()
# Out:
#         state  sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# 0     Alabama         0.05         0.06         0.07         1.00
# 1      Alaska         0.38         0.43         0.41         0.65
# 2     Arizona         0.30         0.29         0.31         0.62
# 3    Arkansas         0.03         0.05         0.06         1.00
# 4  California         0.53         0.60         0.63         0.31
#
#    act_part_18  act_part_19  perc_college_bound  perc_bach
# 0         1.00         1.00              0.6595     0.2715
# 1         0.33         0.38              0.4114     0.2696
# 2         0.66         0.73              0.5009     0.2912
# 3         1.00         1.00              0.6313     0.2596
# 4         0.27         0.23              0.6601     0.3663

# %%
part_colg[part_colg.isin([1.00]).any(axis=1)]
# Out:
#              state  sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# 0          Alabama         0.05         0.06         0.07         1.00
# 3         Arkansas         0.03         0.05         0.06         1.00
# 5         Colorado         0.11         1.00         1.00         1.00
# 6      Connecticut         1.00         1.00         1.00         0.31
# 7         Delaware         1.00         1.00         1.00         0.18
# 8          Florida         0.83         0.56         1.00         0.73
# 11           Idaho         0.93         1.00         1.00         0.38
# 12        Illinois         0.09         0.99         1.00         0.93
# 16        Kentucky         0.04         0.04         0.04         1.00
# 17       Louisiana         0.04         0.04         0.05         1.00
# 21        Michigan         1.00         1.00         1.00         0.29
# 22       Minnesota         0.03         0.04         0.04         1.00
# ...

# %% [markdown]
# ##### Florida's SAT participation jumped to near 100% starting in 2019, as did Rhode Island's in 2018, indicating that both states likely started requiring the SAT. We can also see that Colorado and Illinois most likely switched from requiring the ACT to the SAT after 2017.

# %% [markdown]
# #####

# %%
part_colg.sort_values('perc_college_bound', ascending=False).head()
# Out:
#             state  sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# 23    Mississippi         0.02         0.03         0.03         1.00
# 6     Connecticut         1.00         1.00         1.00         0.31
# 20  Massachusetts         0.76         0.80         0.81         0.29
# 29     New Jersey         0.70         0.82         0.82         0.34
# 31       New York         0.67         0.79         0.79         0.31
#
#     act_part_18  act_part_19  perc_college_bound  perc_bach
# 23         1.00         1.00              0.8047     0.2424
# 6          0.26         0.22              0.7805     0.4345
# 20         0.25         0.21              0.7409     0.5346
# 29         0.31         0.25              0.7402     0.4722
# 31         0.27         0.22              0.7242     0.4637

# %%
part_colg.sort_values('perc_college_bound', ascending=True).head()
# Out:
#          state  sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# 1       Alaska         0.38         0.43         0.41         0.65
# 11       Idaho         0.93         1.00         1.00         0.38
# 43        Utah         0.03         0.04         0.04         1.00
# 2      Arizona         0.30         0.29         0.31         0.62
# 46  Washington         0.64         0.69         0.70         0.29
#
#     act_part_18  act_part_19  perc_college_bound  perc_bach
# 1          0.33         0.38              0.4114     0.2696
# 11         0.36         0.31              0.4393     0.2781
# 43         1.00         1.00              0.4696     0.3414
# 2          0.66         0.73              0.5009     0.2912
# 46         0.24         0.24              0.5323     0.3936

# %% [markdown]
# ##### Listing the top and bottom five states by percentage of high school grads going directly to college.  Mississippi has the highest rate, and also has 100% participation in the ACT. However, the next 4 states have high SAT participation and lower ACT participation relative to the mean.

# %% [markdown]
# #####

# %%
part_colg.sort_values('perc_bach', ascending=False).head(10)
# Out:
#             state  sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# 20  Massachusetts         0.76         0.80         0.81         0.29
# 29     New Jersey         0.70         0.82         0.82         0.34
# 31       New York         0.67         0.79         0.79         0.31
# 44        Vermont         0.60         0.64         0.66         0.29
# 6     Connecticut         1.00         1.00         1.00         0.31
# 22      Minnesota         0.03         0.04         0.04         1.00
# 19       Maryland         0.69         0.76         0.82         0.28
# 5        Colorado         0.11         1.00         1.00         1.00
# 12       Illinois         0.09         0.99         1.00         0.93
# 45       Virginia         0.65         0.68         0.68         0.29
#
#     act_part_18  act_part_19  perc_college_bound  perc_bach
# 20         0.25         0.21              0.7409     0.5346
# 29         0.31         0.25              0.7402     0.4722
# ...

# %%
part_colg.sort_values('perc_bach', ascending=True).head()
# Out:
#           state  sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# 30   New Mexico         0.11         0.16         0.18         0.66
# 27       Nevada         0.26         0.23         0.20         1.00
# 23  Mississippi         0.02         0.03         0.03         1.00
# 3      Arkansas         0.03         0.05         0.06         1.00
# 35     Oklahoma         0.07         0.08         0.22         1.00
#
#     act_part_18  act_part_19  perc_college_bound  perc_bach
# 30         0.67         0.63              0.6071     0.2324
# 27         1.00         1.00              0.5816     0.2348
# 23         1.00         1.00              0.8047     0.2424
# 3          1.00         1.00              0.6313     0.2596
# 35         1.00         1.00              0.5727     0.2614

# %% [markdown]
# ##### Listing the top and bottom five states by percentage of the population (Ages 25-34) with Bachelor's degrees.  The top have high SAT participation relative to the mean, while the bottom five have high ACT participation relative to the mean.

# %% [markdown]
# ######

# %%
#summary statistics for states that have 100% participation for either test
print(part_colg[ (part_colg['act_part_18'] >= 0.95)  |  (part_colg['sat_part_18'] >= 0.95)  ].shape)
part_colg[ (part_colg['act_part_18'] >= 0.95)  |  (part_colg['sat_part_18'] >= 0.95)  ].describe()
# Out:
# (28, 9)
#        sat_part_17  sat_part_18  sat_part_19  act_part_17  act_part_18  \
# count    28.000000    28.000000    28.000000    28.000000    28.000000
# mean      0.311429     0.395714     0.406429     0.790357     0.753214
# std       0.389679     0.436080     0.436265     0.335697     0.368059
# min       0.020000     0.020000     0.020000     0.080000     0.070000
# 25%       0.030000     0.040000     0.040000     0.657500     0.345000
# 50%       0.080000     0.090000     0.140000     1.000000     1.000000
# 75%       0.552500     0.975000     0.992500     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        act_part_19  perc_college_bound  perc_bach
# count    28.000000           28.000000  28.000000
# mean      0.725000            0.626846   0.332575
# std       0.376037            0.078582   0.058987
# min       0.060000            0.439300   0.234800
# 25%       0.300000            0.582500   0.277150
# ...

# %%
#summary statistics for states that do not have a high percentage participation for either test
print(part_colg[ (part_colg['act_part_18'] < 0.7)  &  (part_colg['sat_part_18'] < 0.7)  ].shape)
part_colg[ (part_colg['act_part_18'] < 0.7)  &  (part_colg['sat_part_18'] < 0.7)  ].describe()
# Out:
# (13, 9)
#        sat_part_17  sat_part_18  sat_part_19  act_part_17  act_part_18  \
# count    13.000000    13.000000    13.000000    13.000000    13.000000
# mean      0.452308     0.471538     0.572308     0.492308     0.448462
# std       0.247493     0.217556     0.283230     0.178660     0.188496
# min       0.020000     0.030000     0.030000     0.290000     0.240000
# 25%       0.300000     0.290000     0.410000     0.310000     0.270000
# 50%       0.530000     0.560000     0.660000     0.450000     0.420000
# 75%       0.630000     0.640000     0.680000     0.660000     0.660000
# max       0.830000     0.690000     1.000000     0.730000     0.680000
#
#        act_part_19  perc_college_bound  perc_bach
# count    13.000000           13.000000  13.000000
# mean      0.416154            0.580938   0.333108
# std       0.181959            0.076581   0.064262
# min       0.200000            0.411400   0.232400
# 25%       0.240000            0.548500   0.291200
# ...

# %%
#summary statistics for states with 100% SAT participation
print(part_colg[ part_colg['sat_part_18'] == 1  ].shape)
part_colg[ part_colg['sat_part_18'] == 1  ].describe()
# Out:
# (5, 9)
#        sat_part_17  sat_part_18  sat_part_19  act_part_17  act_part_18  \
# count     5.000000          5.0          5.0      5.00000     5.000000
# mean      0.808000          1.0          1.0      0.43200     0.262000
# std       0.391369          0.0          0.0      0.32553     0.072938
# min       0.110000          1.0          1.0      0.18000     0.170000
# 25%       0.930000          1.0          1.0      0.29000     0.220000
# 50%       1.000000          1.0          1.0      0.31000     0.260000
# 75%       1.000000          1.0          1.0      0.38000     0.300000
# max       1.000000          1.0          1.0      1.00000     0.360000
#
#        act_part_19  perc_college_bound  perc_bach
# count     5.000000            5.000000   5.000000
# mean      0.224000            0.631360   0.360840
# std       0.069857            0.130515   0.067924
# min       0.130000            0.439300   0.278100
# 25%       0.190000            0.579800   0.327300
# ...

# %%
#summary statistics for states with 100% ACT participation
print(part_colg[ part_colg['act_part_18'] == 1  ].shape)
part_colg[ part_colg['act_part_18'] == 1  ].describe()
# Out:
# (17, 9)
#        sat_part_17  sat_part_18  sat_part_19  act_part_17  act_part_18  \
# count    17.000000    17.000000    17.000000    17.000000         17.0
# mean      0.112941     0.124118     0.140000     0.975882          1.0
# std       0.154950     0.164395     0.184763     0.069916          0.0
# min       0.020000     0.030000     0.030000     0.750000          1.0
# 25%       0.030000     0.040000     0.040000     1.000000          1.0
# 50%       0.040000     0.050000     0.060000     1.000000          1.0
# 75%       0.100000     0.100000     0.190000     1.000000          1.0
# max       0.500000     0.550000     0.680000     1.000000          1.0
#
#        act_part_19  perc_college_bound  perc_bach
# count    17.000000           17.000000  17.000000
# mean      0.976471            0.622994   0.303376
# std       0.066796            0.074401   0.044153
# min       0.780000            0.469600   0.234800
# 25%       1.000000            0.581600   0.271500
# ...

# %% [markdown]
# ##### Listing the above summary statistics to show relationship with test participation and college enrollment/completion.  States with >=95% participation in either test showed slightly higher rates of students enrolling in college directly after high school and a similar rate of college graduates(age 25-34) when compared to states without a high participation rate in either test.
# ##### States with 100% SAT participation show slightly higher college enrollment out of high school and a slightly higher rate of college graduates than states with 100% ACT participation.

# %% [markdown]
# ######

# %%
part_colg.corr()
# Out:
#                     sat_part_17  sat_part_18  sat_part_19  act_part_17  \
# sat_part_17            1.000000     0.871233     0.840344    -0.839471
# sat_part_18            0.871233     1.000000     0.951611    -0.750275
# sat_part_19            0.840344     0.951611     1.000000    -0.711053
# act_part_17           -0.839471    -0.750275    -0.711053     1.000000
# act_part_18           -0.791382    -0.866205    -0.822652     0.917604
# act_part_19           -0.806270    -0.885619    -0.864302     0.903279
# perc_college_bound     0.135374     0.104273     0.076641    -0.104700
# perc_bach              0.365628     0.492971     0.414588    -0.472239
#
#                     act_part_18  act_part_19  perc_college_bound  perc_bach
# sat_part_17           -0.791382    -0.806270            0.135374   0.365628
# sat_part_18           -0.866205    -0.885619            0.104273   0.492971
# sat_part_19           -0.822652    -0.864302            0.076641   0.414588
# ...

# %% [markdown]
# ##### Creating a correlation matrix to look for relationships between SAT participation rates, ACT participation rates, rate of high school grads going to college, and percentage of population with Bachelor's degrees or higher

# %% [markdown]
# ##### We can immediately see inverse correlations between SAT and ACT participation. In the next section, we will create a heatmap to get a better visualization for relationship between test participation and higher educational attainment.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### Seaborn's Heatmap

# %%
plt.figure(figsize=(6,6)) 
plt.title('SAT ACT Participation and Higher Education')
sns.heatmap(part_colg.corr(), cmap='vlag', vmin=-1, annot=True);

# %% [markdown]
# ##### The percentage of high school grads from each state enrolling in college has a very slight positive correlation with SAT participation and a very slight negative correlation with ACT participation, though these are too small to be significant.
# ##### The percentage of the population(ages 25-34) in each state with a college degree has a stronger positive correlation with SAT participation, and a negative correlation with ACT participation.

# %% [markdown]
# #####

# %% [markdown]
# #### Histograms

# %%
#referenced link for subplots   https://www.tutorialspoint.com/how-to-make-two-plots-side-by-side-using-python
plt.subplots(figsize=(14,10))

plt.subplot(221)
plt.hist(part_colg['sat_part_17'], bins=10)  
plt.xlabel('SAT Participation Rate') 
plt.ylim(0, 20)
plt.ylabel('Number of States')
plt.title('SAT Participation 2017');  

plt.subplot(222)
plt.hist(part_colg['act_part_17'], bins=10)  
plt.xlabel('ACT Participation Rate') 
plt.ylim(0, 20)
plt.ylabel('Number of States')
plt.title('ACT Participation 2017');

# %%
plt.subplots(figsize=(14,10))

plt.subplot(221)
plt.hist(part_colg['sat_part_18'], bins=10)  
plt.xlabel('SAT Participation Rate')     
plt.ylim(0, 20)
plt.ylabel('Number of States')
plt.title('SAT Participation Rate 2018');   

plt.subplot(222)
plt.hist(part_colg['act_part_18'], bins=10)  
plt.xlabel('ACT Participation Rate') 
plt.ylim(0, 20)
plt.ylabel('Number of States')
plt.title('ACT Participation 2018');

# %%
plt.subplots(figsize=(14,10))

plt.subplot(221)
plt.hist(part_colg['sat_part_19'], bins=10)  
plt.xlabel('SAT Participation Rate') 
plt.ylim(0, 20)
plt.ylabel('Number of States')
plt.title('SAT Participation 2019');  

plt.subplot(222)
plt.hist(part_colg['act_part_19'], bins=10)  
plt.xlabel('ACT Participation Rate') 
plt.ylim(0, 20)
plt.ylabel('Number of States')
plt.title('ACT Participation 2019');

# %% [markdown]
# ##### Participation rate for both tests is most heavily distributed at 100% and near 0%.  This is most likely due to many states mandating participation in one test or the other. Several states have shifted from the ACT to the SAT since 2017.

# %% [markdown]
# #####

# %% [markdown]
# #### Boxplots

# %%
#referenced link to set x axis tick labels https://stats.stackexchange.com/questions/3476/how-to-name-the-ticks-in-a-python-matplotlib-boxplot
plt.title('SAT Participation Rates 2017-2019')
plt.ylabel('Participation Rate')
sns.boxplot(data=part_colg[['sat_part_17', 'sat_part_18', 'sat_part_19']]).set_xticklabels(['SAT 2017', 'SAT 2018', 'SAT 2019']);

# %%
plt.title('ACT Participation Rates 2017-2019')
plt.ylabel('Participation Rate')
sns.boxplot(data=part_colg[['act_part_17', 'act_part_18', 'act_part_19']]).set_xticklabels(['ACT 2017', 'ACT 2018', 'ACT 2019']);

# %% [markdown]
# ##### The boxplots show that the ACT has a high participation in more states than the SAT, though the gap has gotten smaller since 2017

# %% [markdown]
# #### Scatter Plots

# %%
y=part_colg[['sat_part_17', 'sat_part_18', 'sat_part_19']]
x=part_colg['perc_bach']

# %%
plt.subplots(figsize=(12, 10))

plt.subplot(221)
plt.title('SAT Participation and College Enrollment')
plt.scatter(x=part_colg[['sat_part_17', 'sat_part_18', 'sat_part_19']], y=part_colg[['perc_college_bound', 'perc_college_bound', 'perc_college_bound']])
plt.xlabel('SAT Participation Rate 2017-2019')
plt.ylabel('Rate of HS Grads Enrolling in College')

plt.subplot(222)
plt.title('SAT Participation and Higher Education')
plt.scatter(x=part_colg[['sat_part_17', 'sat_part_18', 'sat_part_19']], y=part_colg[['perc_bach', 'perc_bach', 'perc_bach']])
plt.xlabel('SAT Participation Rate 2017-2019')
plt.ylabel('% of Population(25-34) with College Degree')
# Out:
# Text(0, 0.5, '% of Population(25-34) with College Degree')

# %%
plt.subplots(figsize=(12, 10))

plt.subplot(221)
plt.title('ACT Participation and College Enrollment')
plt.scatter(x=part_colg[['act_part_17', 'act_part_18', 'act_part_19']], y=part_colg[['perc_college_bound', 'perc_college_bound', 'perc_college_bound']])
plt.xlabel('ACT Participation Rate 2017-2019')
plt.ylabel('Rate of HS Grads Enrolling in College')

plt.subplot(222)
plt.title('ACT Participation and Higher Education')
plt.scatter(x=part_colg[['act_part_17', 'act_part_18', 'act_part_19']], y=part_colg[['perc_bach', 'perc_bach', 'perc_bach']])
plt.xlabel('ACT Participation Rate 2017-2019')
plt.ylabel('% of Population(25-34) with College Degree')
# Out:
# Text(0, 0.5, '% of Population(25-34) with College Degree')

# %% [markdown]
# ##### The scatterplots for SAT participation rate show a positive correlation with attainment of higher education, while ACT participation shows little or slightly negative correlation.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*
# In conclusion,
# I recommend the state partner with the College Board to make the SAT mandatory for all high school graduates. Having a contract to administer the SAT will make college-entrance testing more accessible for all students, and will eliminate the need for the state to administer its own benchmark tests. While the ACT has had a higher number of states mandating the ACT in recent years, recent trends have shown a shift towards the SAT, and we should choose the same.  Since its redesign in 2016, the SAT is more closely aligned with state education benchmarks and is able to provide more resources for testing and preparation. Also, while participation in these tests did not show to be a strong predictor of with future success, SAT participation did show a slight correlation with attainment of higher education.  Along with forming a partnership with the College Board, it is recommended that the state work with local school districts to provide resources and testing days for students.  It is also recommended that further research be conducted to follow long-term trends between college-entrance exam participation and student success.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
